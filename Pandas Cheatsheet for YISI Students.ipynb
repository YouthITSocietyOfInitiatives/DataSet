# %% [markdown]
# ## Importing Pandas

# %%
#as pd is shorten var for pandas
import pandas as pd

# %% [markdown]
# ## Setting up the var name for custom dataframe

# %% [markdown]
# Columns option make changes to column that we want to show.<br>
# Index option make changes to row that we want to show

# %%
df = pd.DataFrame([[2,4,6],[10,20,30]],columns=["Price","Age","Value"],index=["First","Second"])

# %%
df
# Out:
#         Price  Age  Value
# First       2    4      6
# Second     10   20     30

# %% [markdown]
# And We can use Dict as Column and its data.

# %%
df1 = pd.DataFrame([{"Name":"Lynn"},{"Name":"Htut"}])

# %%
df1
# Out:
#    Name
# 0  Lynn
# 1  Htut

# %%
df1 = pd.DataFrame([{"Name":"Lynn"},{"Surename":"Nyan","Name":"Htut"},{"Name":"Htut"}])
df1
# Out:
#    Name Surename
# 0  Lynn      NaN
# 1  Htut     Nyan
# 2  Htut      NaN

# %%
df2 = pd.DataFrame([{"Name":"Lynn","Surename":"Htut"},{"Name":"Htut"},{"Surename":"Nyan"}],index=["First","Sec","third"])

# %%
df2
# Out:
#        Name Surename
# First  Lynn     Htut
# Sec    Htut      NaN
# third   NaN     Nyan

# %%
df.mean()
# Out:
# Price     6.0
# Age      12.0
# Value    18.0
# dtype: float64

# %%
type(df.mean().mean())
# Out:
# float

# %%
dir
# Out:
# <function dir>

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5628-FBA2
#
#  Directory of C:\Users\THIS PC\Desktop\Pandas
#
# 12/05/2020  01:59 AM    <DIR>          .
# 12/05/2020  01:59 AM    <DIR>          ..
# 12/05/2020  12:01 AM    <DIR>          .ipynb_checkpoints
# 12/05/2020  01:16 AM    <DIR>          pandas-main
# 06/17/2018  08:21 PM               400 supermarkets.csv
# 06/17/2018  08:21 PM             1,119 supermarkets.json
# 06/17/2018  08:21 PM             9,239 supermarkets.xlsx
# 06/17/2018  08:21 PM               401 supermarkets-commas.txt
# 06/17/2018  08:21 PM               401 supermarkets-semi-colons.txt
# 12/05/2020  01:59 AM            45,887 Untitled.ipynb
#                6 File(s)         57,447 bytes
#                4 Dir(s)  82,417,127,424 bytes free

# %%
df = pd.read_csv("supermarkets.csv")

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pd.read_json("supermarkets.json")

# %%
df2.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df3 = pd.read_excel("supermarkets.xlsx")

# %%
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df5 = pd.read_csv("supermarkets-semi-colons.txt",sep=";")

# %%
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4 = pd.read_csv("supermarkets-commas.txt")

# %%
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# ### Reassigning the columns

# %%
df4.columns=["ID","Address","City","Zip","Country","Name","Employees"]

# %%
df4
# Out:
#    ID          Address           City               Zip Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4.set_index(["ID"])
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df4.set_index(["ID"])
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df4.set_index(["ID"],inplace=True)

# %%
df4
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df4.set_index(["ID"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-283135a505f1> in <module>
# ----> 1 df4.set_index(["ID"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['ID'] are in the columns"

# %%
df4.set_index(["Address"])
# Out:
#                           City               Zip Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df4
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df4.set_index(["Address"],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-a05a7274dc18> in <module>
# ----> 1 df4.set_index(["Address"],inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['Address'] are in the columns"

# %%
df4
# Out:
#                           City               Zip Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %% [markdown]
# ### Inplace make it permanent and remove it from the columns

# %%
df4.set_index(["City"],inplace=True,drop=False)

# %%
df4
# Out:
#                         City               Zip Country         Name  Employees
# City
# San Francisco  San Francisco          CA 94114     USA      Madeira          8
# San Francisco  San Francisco          CA 94119     USA  Bready Shop         15
# San Francisco  San Francisco  California 94114     USA  Super River         25
# San Francisco  San Francisco          CA 94114     USA   Ben's Shop         10
# San Francisco  San Francisco        California     USA      Sanchez         12
# San Francisco  San Francisco          CA 94114     USA   Richvalley         20

# %%
df4.set_index(["Zip"])
# Out:
#                            City Country         Name  Employees
# Zip
# CA 94114          San Francisco     USA      Madeira          8
# CA 94119          San Francisco     USA  Bready Shop         15
# California 94114  San Francisco     USA  Super River         25
# CA 94114          San Francisco     USA   Ben's Shop         10
# California        San Francisco     USA      Sanchez         12
# CA 94114          San Francisco     USA   Richvalley         20

# %% [markdown]
# ### But Drop helps not to pop out the index from columns

# %%
df4 = df4.set_index(["Zip"])

# %%
df4
# Out:
#                            City Country         Name  Employees
# Zip
# CA 94114          San Francisco     USA      Madeira          8
# CA 94119          San Francisco     USA  Bready Shop         15
# California 94114  San Francisco     USA  Super River         25
# CA 94114          San Francisco     USA   Ben's Shop         10
# California        San Francisco     USA      Sanchez         12
# CA 94114          San Francisco     USA   Richvalley         20

# %%
df4.loc["California 94114":"California","City":"Employees"]
# Out:
#                            City Country         Name  Employees
# Zip
# California 94114  San Francisco     USA  Super River         25
# CA 94114          San Francisco     USA   Ben's Shop         10
# California        San Francisco     USA      Sanchez         12

# %% [markdown]
# ### This is how we use slicing in pandas

# %%
df4.loc["California","Employees"]
# Out:
# 12

# %%
list(df4.loc[:,"Employees"])
# Out:
# [8, 15, 25, 10, 12, 20]

# %%
df5 = pd.read_csv("supermarkets.csv")

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.set_index("Address",inplace=True)

# %%
df5
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df5.iloc[0:3,0:5] #index loc
# Out:
#                 ID           City             State Country         Name
# Address
# 3666 21st St     1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114     USA  Super River

# %%
df5.iloc[3,0:5]
# Out:
# ID                     4
# City       San Francisco
# State           CA 94114
# Country              USA
# Name          Ben's Shop
# Name: 3995 23rd St, dtype: object

# %% [markdown]
# ### Just adding index number grab only its character

# %%
df5.drop("State",1)
# Out:
#    ID          Address           City Country         Name  Employees
# 0   1     3666 21st St  San Francisco     USA      Madeira          8
# 1   2   735 Dolores St  San Francisco     USA  Bready Shop         15
# 2   3      332 Hill St  San Francisco     USA  Super River         25
# 3   4     3995 23rd St  San Francisco     USA   Ben's Shop         10
# 4   5  1056 Sanchez St  San Francisco     USA      Sanchez         12
# 5   6  551 Alvarado St  San Francisco     USA   Richvalley         20

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.drop("City",1)
# Out:
#    ID          Address             State Country         Name  Employees
# 0   1     3666 21st St          CA 94114     USA      Madeira          8
# 1   2   735 Dolores St          CA 94119     USA  Bready Shop         15
# 2   3      332 Hill St  California 94114     USA  Super River         25
# 3   4     3995 23rd St          CA 94114     USA   Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA      Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df5.drop("City",1)
# Out:
#    ID          Address             State Country         Name  Employees
# 0   1     3666 21st St          CA 94114     USA      Madeira          8
# 1   2   735 Dolores St          CA 94119     USA  Bready Shop         15
# 2   3      332 Hill St  California 94114     USA  Super River         25
# 3   4     3995 23rd St          CA 94114     USA   Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA      Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df5.drop(df5.index)
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.drop(df5.columns[0:3],1)
# Out:
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df5.drop(df5.index[0:3],0)
# Out:
#    ID          Address           City       State Country        Name  \
# 3   4     3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop
# 4   5  1056 Sanchez St  San Francisco  California     USA     Sanchez
# 5   6  551 Alvarado St  San Francisco    CA 94114     USA  Richvalley
#
#    Employees
# 3         10
# 4         12
# 5         20

# %%
df5.set
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df5.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
len(df5.index)
# Out:
# 6

# %%
df5["Continent"] = ["North America"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-233a5191d994> in <module>
# ----> 1 df5["Continent"] = ["North America"]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3762
#    3763             # turn me into an ndarray
# ...

# %%
df5.shape
# Out:
# (6, 7)

# %%
df5.shape[0]
# Out:
# 6

# %%
df5.shape[1]
# Out:
# 7

# %%
df5["Continent"] = df5.shape[0]* ["North America"]

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
df5["Continent"] = df5["Country"] + "," + "North America"

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees          Continent
# 0          8  USA,North America
# 1         15  USA,North America
# 2         25  USA,North America
# 3         10  USA,North America
# 4         12  USA,North America
# 5         20  USA,North America

# %%
df5["Zip"] = df5["State"] + "," + "11141"

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees          Continent                     Zip
# 0          8  USA,North America          CA 94114,11141
# 1         15  USA,North America          CA 94119,11141
# 2         25  USA,North America  California 94114,11141
# 3         10  USA,North America          CA 94114,11141
# 4         12  USA,North America        California,11141
# 5         20  USA,North America          CA 94114,11141

# %%
df5_t = df5.T

# %%
df5_t
# Out:
#                            0                  1                       2  \
# ID                         1                  2                       3
# Address         3666 21st St     735 Dolores St             332 Hill St
# City           San Francisco      San Francisco           San Francisco
# State               CA 94114           CA 94119        California 94114
# Country                  USA                USA                     USA
# Name                 Madeira        Bready Shop             Super River
# Employees                  8                 15                      25
# Continent  USA,North America  USA,North America       USA,North America
# Zip           CA 94114,11141     CA 94119,11141  California 94114,11141
#
#                            3                  4                  5
# ID                         4                  5                  6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# ...

# %%
df5_t["My Address"] = ["My ID","My City","My State","My Country","My Name","My Employees","My Employees","My Continent","My Zip"]

# %%
df5_t
# Out:
#                            0                  1                       2  \
# ID                         1                  2                       3
# Address         3666 21st St     735 Dolores St             332 Hill St
# City           San Francisco      San Francisco           San Francisco
# State               CA 94114           CA 94119        California 94114
# Country                  USA                USA                     USA
# Name                 Madeira        Bready Shop             Super River
# Employees                  8                 15                      25
# Continent  USA,North America  USA,North America       USA,North America
# Zip           CA 94114,11141     CA 94119,11141  California 94114,11141
#
#                            3                  4                  5  \
# ID                         4                  5                  6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# ...

# %%
df5 = df5_t.T

# %%
df5
# Out:
#                ID          Address           City             State  Country  \
# 0               1     3666 21st St  San Francisco          CA 94114      USA
# 1               2   735 Dolores St  San Francisco          CA 94119      USA
# 2               3      332 Hill St  San Francisco  California 94114      USA
# 3               4     3995 23rd St  San Francisco          CA 94114      USA
# 4               5  1056 Sanchez St  San Francisco        California      USA
# 5               6  551 Alvarado St  San Francisco          CA 94114      USA
# My Address  My ID          My City       My State        My Country  My Name
#
#                     Name     Employees          Continent  \
# 0                Madeira             8  USA,North America
# 1            Bready Shop            15  USA,North America
# 2            Super River            25  USA,North America
# 3             Ben's Shop            10  USA,North America
# 4                Sanchez            12  USA,North America
# ...
